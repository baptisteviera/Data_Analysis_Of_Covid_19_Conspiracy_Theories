# %% [markdown]
# # Twitter API

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

import json
import glob
import os

import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyD807g4CS6Cn-3fe-CVPvXnhK3269kdrQY')

# %% [markdown]
# ## Helper Funtions

# %%
# Renvoie une dataframe avec le contenu de tous les fichiers .json du dossier passé en argument
def createDF(path_to_folder, test_set=False):
    
    os.chdir(path_to_folder)

    df_results = pd.DataFrame(columns=['contributors', 'coordinates', 'created_at', 'display_text_range',
           'entities', 'extended_tweet', 'favorite_count', 'favorited',
           'filter_level', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
           'in_reply_to_status_id', 'in_reply_to_status_id_str',
           'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
           'lang', 'matching_rules', 'place', 'possibly_sensitive', 'quote_count',
           'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
           'quoted_status_permalink', 'reply_count', 'retweet_count', 'retweeted',
           'retweeted_status', 'source', 'text', 'truncated', 'user','grbfcj','fghjk'])
        
    for filename in glob.glob("*.json"):
        data = json.load(open(filename))
        df_current = pd.DataFrame(data["results"])
        df_results = pd.concat([df_results, df_current], sort=False)
    
    if test_set:
        df_results = df_results.sample(10)
    
    return df_results

# %%
# Ajoute une colonne date à partir de la colonne created_at
map_month = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6, 'Jul':7, 'Aug':8,'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12,}

def extractDate(df):
    # création d'une colonne date avec les premiers caractères de la colonne created_at 
    df['date'] = df.created_at.str[:10]
    
    # division de la colonne date en un tuple new = weekday, month, date
    new = df['date'].str.split(' ', n = 2, expand = True)
    
    # ajout des colonnes day, month, year
    df['day'] = new[2] 
    df['month'] = new[1] 
    df.month = df.month.map(map_month)
    df['year'] = '2020'
    
    # modification de la colonne date pour avoir le format yyyy-mm-dd
    df['date'] = df['year'].str.cat(df[['month', 'day']].astype(str), sep="-")
    df['date'] = df['date'].astype('datetime64')
    
    # suppression des colonnes inutiles
    del df['day']
    del df['month']
    del df['year']

# %%
# Fonction d'affichage d'un histogramme pour une dataframe avec une colonne date (stack overflow)
def visualize(df, column_name='date', color='#494949', title=''):
    """
    Visualize a dataframe with a date column.

    Parameters
    ----------
    df : Pandas dataframe
    column_name : str
        Column to visualize
    color : str
    title : str
    """
    plt.figure(figsize=(20, 10))
    ax = (df[column_name].groupby([df[column_name].dt.month,df[column_name].dt.day])
                         .count()).plot(kind="bar", color=color)
    ax.set_facecolor('#ffffff')
    ax.set_xlabel("jour")
    ax.set_ylabel("nombre de tweets")
    ax.set_title(title)
    plt.show()

# %%
def extractUserfromDf (df):
    df_results = pd.DataFrame(columns = [
          "id",
          "id_str",
          "name",
          "screen_name",
          "location",
          "url",
          "description",
          "translator_type",
          "protected",
          "verified",
          "followers_count",
          "friends_count",
          "listed_count",
          "favourites_count",
          "statuses_count",
          "created_at",
          "utc_offset",
          "time_zone",
          "geo_enabled",
          "lang",
          "contributors_enabled",
          "is_translator",
          "profile_background_color",
          "profile_background_image_url",
          "profile_background_image_url_https",
          "profile_background_tile",
          "profile_link_color",
          "profile_sidebar_border_color",
          "profile_sidebar_fill_color",
          "profile_text_color",
          "profile_use_background_image",
          "profile_image_url",
          "profile_image_url_https",
          "profile_banner_url",
          "default_profile",
          "default_profile_image",
          "following",
          "follow_request_sent",
          "notifications"])
    
    for i in range(df.shape[0]):
        current_dict = df['user'].iloc[i]
        temp_df = pd.DataFrame(current_dict, index=[0])
        df_results = pd.concat([df_results, temp_df], sort=False)
    
    return df_results

# %%
def extractUserReply(df):
    df_results = pd.DataFrame(columns=['contributors', 'coordinates', 'created_at', 'display_text_range',
      'entities', 'extended_tweet', 'favorite_count', 'favorited',
      'filter_level', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
      'in_reply_to_status_id', 'in_reply_to_status_id_str',
      'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
      'lang', 'matching_rules', 'place', 'possibly_sensitive', 'quote_count',
      'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
      'quoted_status_permalink', 'reply_count', 'retweet_count', 'retweeted',
      'retweeted_status', 'source', 'text', 'truncated', 'user'])
    
    for i in range(df.shape[0]):
        current_dict = df['retweeted_status'].iloc[i]
        current_dict_str = json.dumps(current_dict)
        a_json = json.loads(current_dict_str)
        temp_df = (pd.DataFrame.from_dict(a_json, orient="index")).T
        df_results = pd.concat([df_results, temp_df], sort=False)
    
    df_results = extractUserfromDf(df_results)
    
    return (df_results)

# %%
# Returns all users involved in a df of tweets (authors and auhors they are retweeting)
def all_users_from(df):
    users = extractUserfromDf(df)
    reply_to = extractUserReply(df)
    df_results = pd.concat([users, reply_to])
    df_results = df_results.dropna(subset=['location'])
    df_results = df_results[df_results.location != 'France']
    df_results = df_results[df_results.location != 'france']
    df_results = df_results[df_results.location != 'Somewhere']
    df_results = df_results[df_results.location != 'earth']
    return df_results

# %%
def nodes_from_df(df):
    df_results = all_users_from(df)
    df_results['lon'] = 0.0
    df_results['lat'] = 0.0
    df_results.index = range(df_results.shape[0])
    for i in range(df_results.shape[0]):
        #print("Localisation courante : ", df_results.iloc[i]['location'])
        current_geocode = gmaps.geocode(df_results.iloc[i]['location'])

        
        if current_geocode:  
            print(i, "- GPS : ", current_geocode[0]['geometry']['location'])
            df_results.at[i,'lon'] = current_geocode[0]['geometry']['location']['lng'] # get value of a specific cell
            df_results.at[i,'lat'] = current_geocode[0]['geometry']['location']['lat']
        else:
            print(i, "- Wrong geo !")
        
    return (df_results[["screen_name", "lon", "lat"]].drop_duplicates())

# %%
nodes_hydro_all.to_csv(r'/Users/benji/Desktop/GI01/IC05/Projet/Essaiv3/Network/nodes_hydrol.csv',index=False)

# %%
nodes_5G_all =  nodes_from_df(df_5g_wnan)
# Out:
# 0 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 1 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 2 - GPS :  {'lat': 43.124228, 'lng': 5.928}
# 3 - GPS :  {'lat': 43.2951, 'lng': -0.370797}
# 4 - GPS :  {'lat': 45.54151, 'lng': 3.248128}
# 5 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 6 - GPS :  {'lat': 50.62925, 'lng': 3.057256}
# 7 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 8 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 9 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 10 - GPS :  {'lat': 53.9332706, 'lng': -116.5765035}
# 11 - GPS :  {'lat': 46.2196009, 'lng': 6.079443299999999}
# 12 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 13 - GPS :  {'lat': 48.3181795, 'lng': 7.441624099999999}
# 14 - GPS :  {'lat': 46.818188, 'lng': 8.227511999999999}
# 15 - GPS :  {'lat': 47.162494, 'lng': 19.5033041}
# 16 - Wrong geo !
# 17 - GPS :  {'lat': 28.033886, 'lng': 1.659626}
# 18 - GPS :  {'lat': 48.841082, 'lng': 2.999366}
# 19 - GPS :  {'lat': 37.7794551, 'lng': -122.4103292}
# 20 - GPS :  {'lat': 48.97423029999999, 'lng': 2.5102922}
# 21 - GPS :  {'lat': 48.216365, 'lng': -1.697343}
# 22 - GPS :  {'lat': 47.66670329999999, 'lng': -122.3172304}
# 23 - GPS :  {'lat': 44.837789, 'lng': -0.57918}
# 24 - GPS :  {'lat': 40.7467228, 'lng': -73.8938426}
# 25 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 26 - GPS :  {'lat': 46.6613966, 'lng': -1.4482662}
# 27 - GPS :  {'lat': 43.6631908, 'lng': -1.3926315}
# 28 - GPS :  {'lat': 50.220028, 'lng': 1.631823}
# 29 - GPS :  {'lat': 30.0124722, 'lng': -90.0602893}
# 30 - GPS :  {'lat': 49.524641, 'lng': 0.8828328999999999}
# 31 - GPS :  {'lat': 45.4320081, 'lng': 2.0195909}
# 32 - GPS :  {'lat': 48.956682, 'lng': 4.363073}
# 33 - Wrong geo !
# 34 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 35 - GPS :  {'lat': 41.8808453, 'lng': -87.63104779999999}
# 36 - GPS :  {'lat': 26.0700938, 'lng': -80.14430639999999}
# 37 - GPS :  {'lat': 48.8744233, 'lng': 6.2080932}
# 38 - GPS :  {'lat': 49.1193089, 'lng': 6.175715599999999}
# 39 - GPS :  {'lat': 47.1343207, 'lng': 6.0223016}
# 40 - GPS :  {'lat': 45.74948999999999, 'lng': -0.7733188}
# 41 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 42 - GPS :  {'lat': 45.1695797, 'lng': 5.4502821}
# 43 - GPS :  {'lat': 46.131859, 'lng': 3.425488}
# 44 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 45 - GPS :  {'lat': 43.567172, 'lng': 4.1925869}
# 46 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 47 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 48 - GPS :  {'lat': 48.00611000000001, 'lng': 0.199556}
# 49 - GPS :  {'lat': 37.180424, 'lng': -93.216708}
# 50 - GPS :  {'lat': 48.754517, 'lng': 2.214436}
# 51 - GPS :  {'lat': 45.9163174, 'lng': 6.6075841}
# 52 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 53 - GPS :  {'lat': 38.9784551, 'lng': -76.49451049999999}
# 54 - GPS :  {'lat': 48.8698849, 'lng': 2.3253266}
# 55 - GPS :  {'lat': 48.87987039999999, 'lng': 0.1712529}
# 56 - GPS :  {'lat': 34.0834335, 'lng': -118.3529549}
# 57 - GPS :  {'lat': 43.94931700000001, 'lng': 4.805528}
# 58 - GPS :  {'lat': 49.418762, 'lng': 0.233262}
# 59 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 60 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 61 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 62 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 63 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 64 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 65 - GPS :  {'lat': -41.8101472, 'lng': -68.9062689}
# 66 - GPS :  {'lat': 40.723567, 'lng': -73.904884}
# 67 - GPS :  {'lat': 41.919229, 'lng': 8.738635}
# 68 - GPS :  {'lat': 43.637844, 'lng': -1.420939}
# 69 - GPS :  {'lat': 42.1730098, 'lng': 0.0253621}
# 70 - GPS :  {'lat': 38.8985658, 'lng': -77.04428419999999}
# 71 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 72 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 73 - Wrong geo !
# 74 - GPS :  {'lat': 42.0396042, 'lng': 9.012892599999999}
# 75 - GPS :  {'lat': 43.347652, 'lng': 5.397247999999999}
# 76 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 77 - GPS :  {'lat': 40.7467228, 'lng': -73.8938426}
# 78 - GPS :  {'lat': 48.117266, 'lng': -1.6777926}
# 79 - GPS :  {'lat': 48.2020471, 'lng': -2.9326435}
# 80 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 81 - GPS :  {'lat': 44.9957745, 'lng': 5.9293476}
# 82 - GPS :  {'lat': 46.670511, 'lng': -1.426442}
# 83 - GPS :  {'lat': 45.1810359, 'lng': 5.7284618}
# 84 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 85 - GPS :  {'lat': 45.6402905, 'lng': 5.6864994}
# 86 - GPS :  {'lat': 47.322047, 'lng': 5.04148}
# 87 - GPS :  {'lat': 46.818188, 'lng': 8.227511999999999}
# 88 - GPS :  {'lat': 50.291002, 'lng': 2.777535}
# 89 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 90 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 91 - GPS :  {'lat': 51.50739069999999, 'lng': -0.1276999}
# 92 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 93 - Wrong geo !
# 94 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 95 - GPS :  {'lat': 44.933393, 'lng': 4.89236}
# 96 - GPS :  {'lat': 44.73118960000001, 'lng': 5.2266675}
# 97 - GPS :  {'lat': 44.9957745, 'lng': 5.9293476}
# 98 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 99 - GPS :  {'lat': 40.6719437, 'lng': -73.9836679}
# 100 - GPS :  {'lat': 48.856898, 'lng': 2.528373}
# 101 - Wrong geo !
# 102 - GPS :  {'lat': 44.759629, 'lng': 4.5624426}
# 103 - GPS :  {'lat': 37.6408051, 'lng': -97.3880416}
# 104 - Wrong geo !
# 105 - GPS :  {'lat': 46.8307957, 'lng': 6.5543666}
# 106 - GPS :  {'lat': 52.4919634, 'lng': 13.351096}
# 107 - GPS :  {'lat': 43.7305166, 'lng': -79.2771696}
# 108 - GPS :  {'lat': 45.516321, 'lng': -122.630743}
# 109 - GPS :  {'lat': 44.19997, 'lng': 4.73083}
# 110 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 111 - GPS :  {'lat': 33.8175173, 'lng': -6.2375947}
# 112 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 113 - GPS :  {'lat': 39.0273577, 'lng': -94.5836724}
# 114 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 115 - GPS :  {'lat': 39.0273577, 'lng': -94.5836724}
# 116 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 117 - Wrong geo !
# 118 - GPS :  {'lat': 50.562895, 'lng': 2.899697}
# 119 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 120 - GPS :  {'lat': 36.0971945, 'lng': -115.1466648}
# 121 - Wrong geo !
# 122 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 123 - Wrong geo !
# 124 - Wrong geo !
# 125 - Wrong geo !
# 126 - GPS :  {'lat': -0.9962972000000001, 'lng': -77.81360350000001}
# 127 - GPS :  {'lat': 34.9466672, 'lng': -92.05914589999999}
# 128 - GPS :  {'lat': 48.828508, 'lng': 2.2188068}
# 129 - GPS :  {'lat': 45.1695797, 'lng': 5.4502821}
# 130 - GPS :  {'lat': 37.180424, 'lng': -93.216708}
# 131 - Wrong geo !
# 132 - GPS :  {'lat': 45.43254779999999, 'lng': -73.4791424}
# 133 - GPS :  {'lat': 45.4871973, 'lng': -73.58992839999999}
# 134 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 135 - GPS :  {'lat': 45.5139688, 'lng': -73.5729867}
# 136 - GPS :  {'lat': 45.7519958, 'lng': 0.1534761}
# 137 - Wrong geo !
# 138 - GPS :  {'lat': 43.9351691, 'lng': 6.0679194}
# 139 - GPS :  {'lat': 44.10485200000001, 'lng': 1.08468}
# 140 - GPS :  {'lat': 43.6938221, 'lng': 7.2426997}
# 141 - GPS :  {'lat': 45.7032695, 'lng': 3.3448536}
# 142 - GPS :  {'lat': 48.00611000000001, 'lng': 0.199556}
# 143 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 144 - GPS :  {'lat': 43.9351691, 'lng': 6.0679194}
# 145 - GPS :  {'lat': 46.818188, 'lng': 8.227511999999999}
# 146 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 147 - GPS :  {'lat': 42.43472, 'lng': -83.985}
# 148 - Wrong geo !
# 149 - GPS :  {'lat': 45.695243, 'lng': 4.036709}
# 150 - GPS :  {'lat': 49.1193089, 'lng': 6.175715599999999}
# 151 - GPS :  {'lat': 45.0212762, 'lng': -74.730345}
# 152 - GPS :  {'lat': 48.4585698, 'lng': 2.1569416}
# 153 - GPS :  {'lat': 50.649169, 'lng': 2.8337089}
# 154 - GPS :  {'lat': 45.186071, 'lng': -71.44651}
# 155 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 156 - GPS :  {'lat': 49.1193089, 'lng': 6.175715599999999}
# 157 - GPS :  {'lat': 48.5734053, 'lng': 7.752111299999999}
# 158 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 159 - Wrong geo !
# 160 - GPS :  {'lat': 10.8505159, 'lng': 76.2710833}
# 161 - GPS :  {'lat': 49.0038473, 'lng': -80.8368799}
# 162 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 163 - GPS :  {'lat': 38.624694, 'lng': 34.714151}
# 164 - GPS :  {'lat': 34.0553454, 'lng': -118.249845}
# 165 - GPS :  {'lat': 42.581137, 'lng': 8.894855}
# 166 - GPS :  {'lat': 40.7587402, 'lng': -73.9786736}
# 167 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 168 - GPS :  {'lat': 48.8211, 'lng': 8.008713}
# 169 - GPS :  {'lat': 43.2951, 'lng': -0.370797}
# 170 - GPS :  {'lat': 43.404811, 'lng': 5.053728}
# 171 - GPS :  {'lat': 49.9183927, 'lng': 5.3745927}
# 172 - GPS :  {'lat': 36.4165052, 'lng': -6.1461102}
# 173 - GPS :  {'lat': 49.524641, 'lng': 0.8828328999999999}
# 174 - GPS :  {'lat': 26.252778, 'lng': -98.24291799999999}
# 175 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 176 - Wrong geo !
# 177 - Wrong geo !
# 178 - Wrong geo !
# 179 - GPS :  {'lat': 37.4274745, 'lng': -122.169719}
# 180 - GPS :  {'lat': 44.837789, 'lng': -0.57918}
# 181 - GPS :  {'lat': 49.0615901, 'lng': 2.1581351}
# 182 - GPS :  {'lat': 45.5013261, 'lng': -73.55572819999999}
# 183 - GPS :  {'lat': 33.52059330000001, 'lng': -7.5680595}
# 184 - GPS :  {'lat': 44.837789, 'lng': -0.57918}
# 185 - GPS :  {'lat': 49.41781599999999, 'lng': 2.826145}
# 186 - GPS :  {'lat': 3.8480325, 'lng': 11.5020752}
# 187 - GPS :  {'lat': 45.9018486, 'lng': 6.121139299999999}
# 188 - GPS :  {'lat': 46.1987811, 'lng': -74.4114335}
# 189 - GPS :  {'lat': 47.795818, 'lng': -3.58491}
# 190 - Wrong geo !
# 191 - GPS :  {'lat': 30.2333511, 'lng': -92.6631994}
# 192 - GPS :  {'lat': 47.7632836, 'lng': -0.3299687}
# 193 - Wrong geo !
# 194 - GPS :  {'lat': 48.2020471, 'lng': -2.9326435}
# 195 - GPS :  {'lat': 40.7245257, 'lng': -73.9978069}
# 196 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 197 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 198 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 199 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 200 - Wrong geo !
# 201 - Wrong geo !
# 202 - GPS :  {'lat': 48.00611000000001, 'lng': 0.199556}
# 203 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 204 - GPS :  {'lat': 43.2132151, 'lng': 2.3517703}
# 205 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 206 - GPS :  {'lat': 28.0214916, 'lng': -82.58212189999999}
# 207 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 208 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 209 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 210 - GPS :  {'lat': 48.83419079999999, 'lng': 2.4035444}
# 211 - GPS :  {'lat': 43.499398, 'lng': 1.40982}
# 212 - GPS :  {'lat': 48.816363, 'lng': 2.317384}
# 213 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 214 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 215 - GPS :  {'lat': 34.0522342, 'lng': -118.2436849}
# 216 - GPS :  {'lat': 32.427908, 'lng': 53.688046}
# 217 - Wrong geo !
# 218 - GPS :  {'lat': 53.990129, 'lng': -0.9140249}
# 219 - GPS :  {'lat': 29.0291672, 'lng': -80.8932884}
# 220 - GPS :  {'lat': 48.989323, 'lng': 1.714958}
# 221 - GPS :  {'lat': 45.764321, 'lng': 4.8677617}
# 222 - GPS :  {'lat': 32.8202935, 'lng': -96.63278389999999}
# 223 - GPS :  {'lat': 48.898132, 'lng': 2.3268216}
# 224 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 225 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 226 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 227 - GPS :  {'lat': 48.912259, 'lng': 2.384049}
# 228 - GPS :  {'lat': 48.172402, 'lng': 6.449403}
# 229 - GPS :  {'lat': 48.8029439, 'lng': 2.485429}
# 230 - GPS :  {'lat': 29.0386161, 'lng': -95.42017410000001}
# 231 - GPS :  {'lat': 14.497401, 'lng': -14.452362}
# 232 - GPS :  {'lat': 40.7704481, 'lng': -73.990732}
# 233 - GPS :  {'lat': 44.837789, 'lng': -0.57918}
# 234 - GPS :  {'lat': 43.9351691, 'lng': 6.0679194}
# 235 - GPS :  {'lat': 46.22467899999999, 'lng': -74.046763}
# 236 - GPS :  {'lat': 50.503887, 'lng': 4.469936}
# 237 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 238 - GPS :  {'lat': 46.2475706, 'lng': 5.1307681}
# 239 - GPS :  {'lat': 46.2475706, 'lng': 5.1307681}
# 240 - GPS :  {'lat': 10.8505159, 'lng': 76.2710833}
# 241 - GPS :  {'lat': 28.4796116, 'lng': -81.4693747}
# 242 - GPS :  {'lat': 45.14694859999999, 'lng': 0.7572205}
# 243 - GPS :  {'lat': 49.49437, 'lng': 0.107929}
# 244 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 245 - GPS :  {'lat': 50.62925, 'lng': 3.057256}
# 246 - GPS :  {'lat': 49.894067, 'lng': 2.295753}
# 247 - GPS :  {'lat': 48.7898144, 'lng': -3.44828}
# 248 - GPS :  {'lat': 43.637844, 'lng': -1.420939}
# 249 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 250 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 251 - GPS :  {'lat': 50.48011529999999, 'lng': 2.7937265}
# 252 - GPS :  {'lat': 46.452222, 'lng': 4.120665}
# 253 - GPS :  {'lat': 48.7305769, 'lng': 2.447488}
# 254 - GPS :  {'lat': 43.0724667, 'lng': 2.3813621}
# 255 - GPS :  {'lat': 49.182863, 'lng': -0.370679}
# 256 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 257 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 258 - GPS :  {'lat': 43.8044093, 'lng': -79.3407539}
# 259 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 260 - GPS :  {'lat': 47.7159467, 'lng': -73.591036}
# 261 - GPS :  {'lat': 43.610769, 'lng': 3.876716}
# 262 - GPS :  {'lat': 43.344233, 'lng': 3.215795}
# 263 - GPS :  {'lat': 45.7032695, 'lng': 3.3448536}
# 264 - GPS :  {'lat': 48.924298, 'lng': 2.445676}
# 265 - GPS :  {'lat': 43.0724667, 'lng': 2.3813621}
# 266 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 267 - GPS :  {'lat': 50.8503396, 'lng': 4.3517103}
# 268 - GPS :  {'lat': 46.3115552, 'lng': 3.4167655}
# 269 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 270 - GPS :  {'lat': 48.8499198, 'lng': 2.6370411}
# 271 - GPS :  {'lat': 43.6977066, 'lng': 7.270324800000001}
# 272 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 273 - Wrong geo !
# 274 - GPS :  {'lat': 46.227638, 'lng': 2.213749}
# 275 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 276 - GPS :  {'lat': 49.320257, 'lng': -1.102929}
# 277 - GPS :  {'lat': 43.4969164, 'lng': -1.5075201}
# 278 - GPS :  {'lat': 43.6977066, 'lng': 7.270324800000001}
# 279 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 280 - GPS :  {'lat': 43.6293863, 'lng': 1.367682}
# 281 - GPS :  {'lat': 45.4993048, 'lng': -73.6410569}
# 282 - Wrong geo !
# 283 - GPS :  {'lat': 50.6853626, 'lng': 4.3779197}
# 284 - Wrong geo !
# 285 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 286 - GPS :  {'lat': 47.902964, 'lng': 1.909251}
# 287 - GPS :  {'lat': 41.3890159, 'lng': -73.4966326}
# 288 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 289 - GPS :  {'lat': 40.75123250000001, 'lng': -73.9746565}
# 290 - GPS :  {'lat': 48.8414356, 'lng': 2.2530487}
# 291 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 292 - Wrong geo !
# 293 - Wrong geo !
# 294 - GPS :  {'lat': 50.64185519999999, 'lng': 3.0847065}
# 295 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 296 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 297 - GPS :  {'lat': 48.692054, 'lng': 6.184417}
# 298 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 299 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 300 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 301 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 302 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 303 - GPS :  {'lat': 45.77722199999999, 'lng': 3.087025}
# 304 - GPS :  {'lat': 50.8503396, 'lng': 4.3517103}
# 305 - GPS :  {'lat': 45.49921, 'lng': -73.56823109999999}
# 306 - GPS :  {'lat': 43.6938221, 'lng': 7.2426997}
# 307 - GPS :  {'lat': 46.9567989, 'lng': -1.3501732}
# 308 - GPS :  {'lat': 48.8404073, 'lng': 2.2358031}
# 309 - GPS :  {'lat': 38.677269, 'lng': -87.5286325}
# 310 - GPS :  {'lat': 47.381523, 'lng': -1.711269}
# 311 - GPS :  {'lat': 50.503887, 'lng': 4.469936}
# 312 - GPS :  {'lat': 46.227638, 'lng': 2.213749}
# 313 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 314 - GPS :  {'lat': 50.220028, 'lng': 1.631823}
# 315 - GPS :  {'lat': 42.697283, 'lng': 9.450880999999999}
# 316 - GPS :  {'lat': 42.1730098, 'lng': 0.0253621}
# 317 - GPS :  {'lat': 47.21627489999999, 'lng': -1.5487708}
# 318 - GPS :  {'lat': 48.44964299999999, 'lng': -68.532657}
# 319 - GPS :  {'lat': 29.9575229, 'lng': -90.0618621}
# 320 - GPS :  {'lat': 42.6886591, 'lng': 2.8948332}
# 321 - GPS :  {'lat': 40.0302709, 'lng': -105.2471786}
# 322 - GPS :  {'lat': 47.902964, 'lng': 1.909251}
# 323 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 324 - GPS :  {'lat': 46.002985, 'lng': 5.289254}
# 325 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 326 - GPS :  {'lat': 43.610769, 'lng': 3.876716}
# 327 - GPS :  {'lat': 37.3456569, 'lng': -95.4112203}
# 328 - GPS :  {'lat': 38.8987, 'lng': -77.0264876}
# 329 - Wrong geo !
# 330 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 331 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 332 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 333 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 334 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 335 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 336 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 337 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 338 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 339 - GPS :  {'lat': 46.394984, 'lng': 6.612114}
# 340 - Wrong geo !
# 341 - GPS :  {'lat': 46.227638, 'lng': 2.213749}
# 342 - GPS :  {'lat': 32.9210902, 'lng': 10.4508956}
# 343 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 344 - GPS :  {'lat': 43.529742, 'lng': 5.447426999999999}
# 345 - GPS :  {'lat': 45.764043, 'lng': 4.835659}
# 346 - GPS :  {'lat': 43.529742, 'lng': 5.447426999999999}
# 347 - GPS :  {'lat': 43.529742, 'lng': 5.447426999999999}
# 348 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 349 - GPS :  {'lat': 39.746416, 'lng': -104.979468}
# 350 - GPS :  {'lat': 47.7632836, 'lng': -0.3299687}
# 351 - GPS :  {'lat': 3.8480325, 'lng': 11.5020752}
# 352 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 353 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 354 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 355 - GPS :  {'lat': 41.4428048, 'lng': -85.85879}
# 356 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 357 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 358 - GPS :  {'lat': 3.8480325, 'lng': 11.5020752}
# 359 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 360 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 361 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 362 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 363 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 364 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 365 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 366 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 367 - GPS :  {'lat': 54.5259614, 'lng': 15.2551187}
# 368 - GPS :  {'lat': 49.258329, 'lng': 4.031696}
# 369 - GPS :  {'lat': -4.4419311, 'lng': 15.2662931}
# 370 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 371 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 372 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 373 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 374 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 375 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 376 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 377 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 378 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 379 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 380 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 381 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 382 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 383 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 384 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 385 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 386 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 387 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 388 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 389 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 390 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 391 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 392 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 393 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 394 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 395 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 396 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 397 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 398 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 399 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 400 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 401 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 402 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 403 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 404 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 405 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 406 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 407 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 408 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 409 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 410 - GPS :  {'lat': 43.85413399999999, 'lng': 1.235576}
# 411 - GPS :  {'lat': 45.9018486, 'lng': 6.121139299999999}
# 412 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 413 - GPS :  {'lat': 45.9018486, 'lng': 6.121139299999999}
# 414 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 415 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 416 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 417 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 418 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 419 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 420 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 421 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 422 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 423 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 424 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 425 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 426 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 427 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 428 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 429 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 430 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 431 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 432 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 433 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 434 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 435 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 436 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 437 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 438 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 439 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 440 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 441 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 442 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 443 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 444 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 445 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 446 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 447 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 448 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 449 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 450 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 451 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 452 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 453 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 454 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 455 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 456 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 457 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 458 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 459 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 460 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 461 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 462 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 463 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 464 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 465 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 466 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 467 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 468 - Wrong geo !
# 469 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 470 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 471 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 472 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 473 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 474 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 475 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 476 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 477 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 478 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 479 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 480 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 481 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 482 - Wrong geo !
# 483 - Wrong geo !
# 484 - Wrong geo !
# 485 - Wrong geo !
# 486 - Wrong geo !
# 487 - GPS :  {'lat': 44.633628, 'lng': -1.201676}
# 488 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 489 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 490 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 491 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 492 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 493 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 494 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 495 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 496 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 497 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 498 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 499 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 500 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 501 - GPS :  {'lat': 44.46660199999999, 'lng': 4.22417}
# 502 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 503 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 504 - Wrong geo !
# 505 - Wrong geo !
# 506 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 507 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 508 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 509 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 510 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 511 - GPS :  {'lat': 44.890891, 'lng': 1.217292}
# 512 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 513 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 514 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 515 - GPS :  {'lat': 43.604652, 'lng': 1.444209}
# 516 - GPS :  {'lat': 58.3957606, 'lng': 26.7463007}
# 517 - GPS :  {'lat': 58.3957606, 'lng': 26.7463007}
# 518 - GPS :  {'lat': 58.3957606, 'lng': 26.7463007}
# 519 - GPS :  {'lat': 58.3957606, 'lng': 26.7463007}
# 520 - GPS :  {'lat': 58.3957606, 'lng': 26.7463007}
# 521 - GPS :  {'lat': 43.529742, 'lng': 5.447426999999999}
# 522 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 523 - GPS :  {'lat': 36.1520894, 'lng': -95.9517558}
# 524 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 525 - GPS :  {'lat': 43.529742, 'lng': 5.447426999999999}
# 526 - Wrong geo !
# 527 - Wrong geo !
# 528 - Wrong geo !
# 529 - Wrong geo !
# 530 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 531 - Wrong geo !
# 532 - Wrong geo !
# 533 - Wrong geo !
# 534 - Wrong geo !
# 535 - Wrong geo !
# 536 - Wrong geo !
# 537 - Wrong geo !
# 538 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 539 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 540 - GPS :  {'lat': 41.591369, 'lng': 9.278311}
# 541 - GPS :  {'lat': 45.455569, 'lng': -73.72190599999999}
# 542 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 543 - GPS :  {'lat': 45.6402905, 'lng': 5.6864994}
# 544 - GPS :  {'lat': 42.3212347, 'lng': -82.904342}
# 545 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 546 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 547 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 548 - GPS :  {'lat': 45.4915755, 'lng': -73.8502913}
# 549 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 550 - GPS :  {'lat': 45.4915755, 'lng': -73.8502913}
# 551 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 552 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 553 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 554 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 555 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 556 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 557 - Wrong geo !
# 558 - GPS :  {'lat': 41.9201092, 'lng': -87.6487485}
# 559 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 560 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 561 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 562 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 563 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 564 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 565 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 566 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 567 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 568 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 569 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 570 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 571 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 572 - GPS :  {'lat': 3.8480325, 'lng': 11.5020752}
# 573 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 574 - GPS :  {'lat': 43.7750554, 'lng': 7.199927100000001}
# 575 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 576 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 577 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 578 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 579 - GPS :  {'lat': 46.8138783, 'lng': -71.2079809}
# 580 - GPS :  {'lat': 45.9018486, 'lng': 6.121139299999999}
# 581 - GPS :  {'lat': 43.7750554, 'lng': 7.199927100000001}
# 582 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 583 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 584 - GPS :  {'lat': 47.2734979, 'lng': -2.213848}
# 585 - GPS :  {'lat': 43.7750554, 'lng': 7.199927100000001}
# 586 - GPS :  {'lat': 43.7750554, 'lng': 7.199927100000001}
# 587 - GPS :  {'lat': 47.2734979, 'lng': -2.213848}
# 588 - GPS :  {'lat': 47.2734979, 'lng': -2.213848}
# 589 - GPS :  {'lat': 47.2455864, 'lng': 6.026442299999999}
# 590 - GPS :  {'lat': 39.746416, 'lng': -104.979468}
# 591 - GPS :  {'lat': 47.2455864, 'lng': 6.026442299999999}
# 592 - GPS :  {'lat': -21.115141, 'lng': 55.536384}
# 593 - GPS :  {'lat': 50.6325574, 'lng': 5.5796662}
# 594 - GPS :  {'lat': 50.6325574, 'lng': 5.5796662}
# 595 - GPS :  {'lat': 50.6325574, 'lng': 5.5796662}
# 596 - GPS :  {'lat': 50.6325574, 'lng': 5.5796662}
# 597 - GPS :  {'lat': 46.2475706, 'lng': 5.1307681}
# 598 - GPS :  {'lat': 46.2475706, 'lng': 5.1307681}
# 599 - GPS :  {'lat': 43.836699, 'lng': 4.360054}
# 600 - GPS :  {'lat': 45.7532854, 'lng': -73.4400814}
# 601 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 602 - GPS :  {'lat': 46.2475706, 'lng': 5.1307681}
# 603 - GPS :  {'lat': 3.933889, 'lng': -53.125782}
# 604 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 605 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 606 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 607 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 608 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 609 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 610 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 611 - GPS :  {'lat': 39.746416, 'lng': -104.979468}
# 612 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 613 - GPS :  {'lat': 51.0385173, 'lng': 2.3710423}
# 614 - GPS :  {'lat': 43.296482, 'lng': 5.36978}
# 615 - GPS :  {'lat': 33.6757851, 'lng': -95.5311341}
# 616 - GPS :  {'lat': 43.7101728, 'lng': 7.261953200000001}
# 617 - GPS :  {'lat': 25.817005, 'lng': -80.38167899999999}
# 618 - GPS :  {'lat': 25.817005, 'lng': -80.38167899999999}
# 619 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 620 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 621 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 622 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 623 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 624 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 625 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 626 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 627 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 628 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 629 - GPS :  {'lat': 50.503887, 'lng': 4.469936}
# 630 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 631 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 632 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 633 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 634 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 635 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 636 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 637 - GPS :  {'lat': 48.5734053, 'lng': 7.752111299999999}
# 638 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 639 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 640 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 641 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 642 - GPS :  {'lat': 48.87341199999999, 'lng': 2.324064}
# 643 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 644 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 645 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 646 - GPS :  {'lat': 48.5734053, 'lng': 7.752111299999999}
# 647 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 648 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 649 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 650 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 651 - GPS :  {'lat': 43.9351691, 'lng': 6.0679194}
# 652 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 653 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 654 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 655 - GPS :  {'lat': 44.7002222, 'lng': -0.2995785}
# 656 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 657 - GPS :  {'lat': 47.218371, 'lng': -1.553621}
# 658 - GPS :  {'lat': 50.4144424, 'lng': 1.7262088}
# 659 - GPS :  {'lat': 50.4144424, 'lng': 1.7262088}
# 660 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 661 - GPS :  {'lat': 47.2455864, 'lng': 6.026442299999999}
# 662 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 663 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 664 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 665 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 666 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 667 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 668 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 669 - GPS :  {'lat': 38.8987, 'lng': -77.0264876}
# 670 - GPS :  {'lat': 49.524641, 'lng': 0.8828328999999999}
# 671 - GPS :  {'lat': 49.524641, 'lng': 0.8828328999999999}
# 672 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 673 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 674 - GPS :  {'lat': 48.542105, 'lng': 2.6554}
# 675 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 676 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 677 - GPS :  {'lat': 45.7605474, 'lng': 4.861117699999999}
# 678 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 679 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 680 - GPS :  {'lat': 14.641528, 'lng': -61.024174}
# 681 - GPS :  {'lat': 45.77722199999999, 'lng': 3.087025}
# 682 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 683 - GPS :  {'lat': 32.699635, 'lng': 35.303546}
# 684 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 685 - GPS :  {'lat': 46.88761909999999, 'lng': 9.656999599999999}
# 686 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 687 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 688 - GPS :  {'lat': 48.856614, 'lng': 2.3522219}
# 689 - GPS :  {'lat': 48.62715799999999, 'lng': 2.593706}

# %%
nodes_5G_all.head(691)
# Out:
#          screen_name         lon        lat
# 0          ChanPerco    2.352222  48.856614
# 1        parisimonea    2.352222  48.856614
# 2      ThierryLovato    5.928000  43.124228
# 3       olivierclave   -0.370797  43.295100
# 4      jeromelebon63    3.248128  45.541510
# 5      DimitriHommel    2.352222  48.856614
# 6         Playmogeek    3.057256  50.629250
# 7           Numerama    2.352222  48.856614
# 8      Dagolek_00108    2.352222  48.856614
# 9         voyousebas  -71.207981  46.813878
# 10        rsaAlberta -116.576504  53.933271
# 11       ThomasClone    6.079443  46.219601
# 12          CIRE1418    2.352222  48.856614
# 13        Galadingue    7.441624  48.318179
# 14   DominiqueQuenin    8.227512  46.818188
# 15           sandoly   19.503304  47.162494
# 16        Norbeeeert    0.000000   0.000000
# 17       mahoursamy0    1.659626  28.033886
# 18          Miiilca1    2.999366  48.841082
# 19           KAINDYS -122.410329  37.779455
# 20         Inachiveg    2.510292  48.974230
# 21     ElvisShark357   -1.697343  48.216365
# 22       JackLeuChat -122.317230  47.666703
# 23          ISimonot   -0.579180  44.837789
# 24          elbiarjp  -73.893843  40.746723
# 25        delavennat    2.352222  48.856614
# 26    ElvireDeslande   -1.448266  46.661397
# 27             PHB92   -1.392632  43.663191
# 28           bonuscr    1.631823  50.220028
# 29     NicolasGourin  -90.060289  30.012472
# ..               ...         ...        ...
# 660   BusinessBourse    2.352222  48.856614
# 661      petit_nanne    6.026442  47.245586
# 662       m_brandely    2.352222  48.856614
# 663       m_brandely    2.352222  48.856614
# 664       franceinfo    2.352222  48.856614
# 665       franceinfo    2.352222  48.856614
# 666       franceinfo    2.352222  48.856614
# 667       franceinfo    2.352222  48.856614
# 668     revue2presse    2.352222  48.856614
# 669        Rom1_0399  -77.026488  38.898700
# 670     PATTYCIA1957    0.882833  49.524641
# 671     PATTYCIA1957    0.882833  49.524641
# 672       LAttendait  -61.024174  14.641528
# 673       LAttendait  -61.024174  14.641528
# 674   FabriceLenoble    2.655400  48.542105
# 675       LAttendait  -61.024174  14.641528
# 676       m_brandely    2.352222  48.856614
# 677        GonesRomz    4.861118  45.760547
# 678       m_brandely    2.352222  48.856614
# 679       LAttendait  -61.024174  14.641528
# 680       LAttendait  -61.024174  14.641528
# 681      PharmacoMed    3.087025  45.777222
# 682       m_brandely    2.352222  48.856614
# 683  RaouItDidierOff   35.303546  32.699635
# 684    BrunoTertrais    2.352222  48.856614
# 685      KheyTorique    9.657000  46.887619
# 686    MichelPoulain    2.352222  48.856614
# 687    MichelPoulain    2.352222  48.856614
# 688    MichelPoulain    2.352222  48.856614
# 689  estellepicard73    2.593706  48.627158
#
# [690 rows x 3 columns]

# %%
geo =  gmaps.geocode('Paris')
if geo:
    print('Wrong Geocode')
else :
    print('OK')
# Out:
# Wrong Geocode

# %%
all_users_from(df_5g_wnan)
# Out:
#                      id               id_str  \
# 0              48130604             48130604
# 0    929360357902225408   929360357902225408
# 0            1074975306           1074975306
# 0              67608740             67608740
# 0    855370072205950976   855370072205950976
# 0             376230264            376230264
# 0              17229611             17229611
# 0              51004523             51004523
# 0    763077024676184064   763077024676184064
# 0    942102274758897664   942102274758897664
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                  https://www.instagram.com/n.anoux/
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                         http://autruchementdit.com/
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                             http://nicolasgourin.fr
# ..                                                ...
# 0                      https://www.businessbourse.com
# 0                           https://profdocestula.fr/
# 0      https://www.yahoo.com/author/matthieu-brandely
# 0      https://www.yahoo.com/author/matthieu-brandely
# 0                                http://franceinfo.fr
# 0                                http://franceinfo.fr
# 0                                http://franceinfo.fr
# 0                                http://franceinfo.fr
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                            https://www.teachreo.com
# 0                                                None
# 0      https://www.yahoo.com/author/matthieu-brandely
# 0                                                None
# 0      https://www.yahoo.com/author/matthieu-brandely
# 0                                                None
# 0                                                None
# 0                http://www.pharmacologie-clermont.fr
# 0      https://www.yahoo.com/author/matthieu-brandely
# 0                                                None
# 0   https://www.frstrategie.org/frs/chercheurs/bru...
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
#
#                                           description translator_type  \
# 0   Relayeur Actu Digitale | Chef de Projet Digita...            none
# 0   Tout comme l'homme, les animaux ressentent le ...            none
# 0   Work Now ⛴️🛳️🆙 #PortsRadeToulon #CCIduVar // B...            none
# 0   #Com et #marketingdigital.#CM #Innovation #Tra...            none
# 0   Aime la randonnée et l’univers vidéo ludique e...            none
# 0   Ex-journaliste radio - #Dircom @HeroiksGroup -...            none
# 0         accessibilité,geek,actu,WTF,serial veilleur            none
# 0   Sinon, ça va ?  🎥 Sur YouTube: http://youtube....            none
# 0                             Je pense donc je suis !            none
# 0   Je renonce au plan mondialiste. C'est ma versi...            none
# 0   Le Réseau santé albertain soutient, sensibilis...            none
# 0   J’ai été écrit par @totodunet. Surtout si vous...            none
# 0   Républicain Français ,citoyen Européen et..du ...            none
# 0                                 42 ! ーcompte persoー            none
# 0   Agitateur de conscience du net (et du pas net)...            none
# 0   Travel brings power and love back into your li...            none
# 0                      🇪🇦🇪🇺\nLibertarien de droite ⚖💸            none
# 0                                                None            none
# 0   • @Miiilca1, 2ème compte de @naaniy973 NAANIYF...            none
# 0   IG:KAINDYS2.0 #TeamPSG #TeamKOMPA SC: kaindys2...            none
# 0   On n'a pas deux coeurs : l'un pour les hommes,...            none
# 0   Eternel insoumis,Liberté Egalité Fraternité,l'...            none
# 0   Merci de me caresser dans le sens du poil avan...            none
# 0                               #Macron2022 🇫🇷🇪🇺 ⭐️⭐️            none
# 0   La nature n'a aucune fin à elle prescrite. Spi...            none
# 0   Ex journaliste , puis bien d’autres choses. Ne...            none
# 0   Citoyenne du monde, l'humanisme est ma priorit...            none
# 0                                  Médecin Interniste            none
# 0   #politique #StandWithScience #LGBTQ #DeGauche ...            none
# 0   Professeur, Entrepreneur, Écologiste, Centrist...            none
# ..                                                ...             ...
# 0   Ici, la seule chose qui doit vous guider, c'es...            none
# 0   #jesuisprofdoc et #RUPN au LP Georges Colomb @...            none
# 0   Journaliste @YahooActuFR ex @CNEWS @rmcinfo, @...            none
# 0   Journaliste @YahooActuFR ex @CNEWS @rmcinfo, @...            none
# 0   L'actualité en direct et en continu avec le mé...            none
# 0   L'actualité en direct et en continu avec le mé...            none
# 0   L'actualité en direct et en continu avec le mé...            none
# 0   L'actualité en direct et en continu avec le mé...            none
# 0   Une sélection hétéroclite des Unes de la Press...            none
# 0                   supercard catch wwe jeu titanfall            none
# 0   la mondialisation est la troisième sœur, après...            none
# 0   la mondialisation est la troisième sœur, après...            none
# 0   J’ouvre l’#EreDigitale l’an 6767 du Calendrier...            none
# 0   J’ouvre l’#EreDigitale l’an 6767 du Calendrier...            none
# 0   Créateur de @teachreo pour dispenser des forma...            none
# 0   J’ouvre l’#EreDigitale l’an 6767 du Calendrier...            none
# 0   Journaliste @YahooActuFR ex @CNEWS @rmcinfo, @...            none
# 0           👑 @ol / @equipedefrance / Balle au centre            none
# 0   Journaliste @YahooActuFR ex @CNEWS @rmcinfo, @...            none
# 0   J’ouvre l’#EreDigitale l’an 6767 du Calendrier...            none
# 0   J’ouvre l’#EreDigitale l’an 6767 du Calendrier...            none
# 0   Fil d'actualité du service hospitalo-universit...            none
# 0   Journaliste @YahooActuFR ex @CNEWS @rmcinfo, @...            none
# 0   Directeur de l'IHU Méditerranée Infection (élu...         regular
# 0   Deputy Director, @FRS_org. Also Senior Fellow,...            none
# 0                                           🇪🇺🛰️🧪🧬✈️🌐            none
# 0   Compte parodique #ÀPeuPrès 🤡 Fan des #Téléfilm...            none
# 0   Compte parodique #ÀPeuPrès 🤡 Fan des #Téléfilm...            none
# 0   Compte parodique #ÀPeuPrès 🤡 Fan des #Téléfilm...            none
# 0   Passionnée de #Cyclisme de #foot de séries #Su...            none
#
#    protected verified  ... profile_text_color profile_use_background_image  \
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             784726                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False     True  ...             333333                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             0C3E53                         True
# 0      False    False  ...             3D1957                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# ..       ...      ...  ...                ...                          ...
# 0      False    False  ...             000000                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False     True  ...             000000                         True
# 0      False     True  ...             000000                         True
# 0      False     True  ...             000000                         True
# 0      False     True  ...             000000                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             333333                         True
# 0      False    False  ...             000000                        False
#
#                                     profile_image_url  \
# 0   http://pbs.twimg.com/profile_images/5518069362...
# 0   http://pbs.twimg.com/profile_images/1321788474...
# 0   http://pbs.twimg.com/profile_images/1252037464...
# 0   http://pbs.twimg.com/profile_images/1010071770...
# 0   http://pbs.twimg.com/profile_images/1250710934...
# 0   http://pbs.twimg.com/profile_images/1055474192...
# 0   http://pbs.twimg.com/profile_images/73759479/p...
# 0   http://pbs.twimg.com/profile_images/1159750563...
# 0   http://pbs.twimg.com/profile_images/1323792387...
# 0   http://pbs.twimg.com/profile_images/1335796999...
# 0   http://pbs.twimg.com/profile_images/6517733294...
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# ..                   ...       ...                 ...           ...
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
# 0                  False      None                None          None
#
# [690 rows x 39 columns]

# %% [markdown]
# ## Load Data

# %%
df_5G = createDF('/Users/benji/Desktop/GI01/IC05/Projet/Essaiv3/5G')
df_5G.shape
# Out:
# (1228, 38)

# %%
df_Gates = createDF('/Users/benji/Desktop/GI01/IC05/Projet/Essaiv3/Gates')
df_Gates.shape
# Out:
# (5183, 38)

# %%
df_hydro = createDF('/Users/benji/Desktop/GI01/IC05/Projet/Essaiv3/Hydroxychloroquine/')
df_hydro.shape
# Out:
# (14087, 38)

# %% [markdown]
# ### Keeping only retweets

# %%
df_gates_wnan = df_Gates.dropna(subset=['retweeted_status'])
df_5g_wnan = df_5G.dropna(subset=['retweeted_status'])
df_hydro_wnan = df_hydro.dropna(subset=['retweeted_status'])

# %%
print(f"Shape Gates: {df_gates_wnan.shape}")
print(f"Shape 5G: {df_5g_wnan.shape}")
print(f"Shape Hydro: {df_hydro_wnan.shape}")
# Out:
# Shape Gates: (4448, 36)
# Shape 5G: (657, 36)
# Shape Hydro: (12637, 36)

# %% [markdown]
# ### Keeping only known localisation

# %%
df_gates_loc = extractUserfromDf(df_gates_wnan.dropna(subset=[''])
df_5g_loc = df_5G.dropna(subset=['retweeted_status'])
df_hydro_loc = df_hydro.dropna(subset=['retweeted_status'])

# %% [markdown]
# ## Extract User

# %%
users_5G = extractUserfromDf(df_5G)

# %% [markdown]
# ## User Extraction & Graph Vertexes definition

# %%
# Renvoie une dataframe avec deux colonnes 'from' et 'to' à partir d'une base de tweets
def edges_from_df(df):
    users = extractUserfromDf(df)
    reply_to = extractUserReply(df)
    df_results = pd.concat([users['screen_name'], reply_to['screen_name']], axis=1, keys=['from', 'to'])
    return df_results

# %%
# Renvoie une dataframe de noeuds à partir d'une base de tweets (3 colonnes : nom, longitude, lattitude)
def nodes_from_edges(df):
    users = extractUserfromDf(df)
    reply_to = extractUserReply(df)
    df_results = pd.concat([users['screen_name'], reply_to['screen_name']], axis=1, keys=['from', 'to'])
    
    df_results = pd.concat([df['from'], df['to']])
    df_results =  pd.DataFrame(pd.unique(df_results), columns=['users'])
    return df_results

# %%
df_edges_5G = edges_from_df(df_5g_wnan)
df_nodes_5G = nodes_from_edges(df_edges_5G)
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_edges_gates = edges_from_df(df_gates_wnan)
df_nodes_gates = nodes_from_edges(df_edges_gates)
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_nodes_5G.to_csv(r'./nodes_5G.csv',index=False)

# %%
df_edges_5G.to_csv(r'./edges_5G.csv',index=False)

# %%
nodes_5G_all2.to_csv(r'/Users/benji/Desktop/GI01/IC05/Projet/Essaiv3/Network/nodes_5Gl2.csv',index=False)
